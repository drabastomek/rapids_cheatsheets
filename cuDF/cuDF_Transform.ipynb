# %% [markdown]
# # cuDF Cheat Sheets sample code
#
# (c) 2020 NVIDIA, Blazing SQL
#
# Distributed under Apache License 2.0

# %% [markdown]
# ### Imports

# %%
import cudf
import numpy as np

# %% [markdown]
# ### Sample DataFrame

# %%
df = cudf.DataFrame(
    [
          (39, 6.88, np.datetime64('2020-10-08T12:12:01'), np.timedelta64(14378,'s'), 'C', 'D', 'data'
            , 'RAPIDS.ai is a suite of open-source libraries that allow you to run your end to end data science and analytics pipelines on GPUs.')
        , (11, 4.21, None,                                 None                     , 'A', 'D', 'cuDF'
            , 'cuDF is a Python GPU DataFrame (built on the Apache Arrow columnar memory format)')
        , (31, 4.71, np.datetime64('2020-10-10T09:26:43'), np.timedelta64(12909,'s'), 'U', 'D', 'memory'
            , 'cuDF allows for loading, joining, aggregating, filtering, and otherwise manipulating tabular data using a DataFrame style API.')
        , (40, 0.93, np.datetime64('2020-10-11T17:10:00'), np.timedelta64(10466,'s'), 'P', 'B', 'tabular'
            , '''If your workflow is fast enough on a single GPU or your data comfortably fits in memory on 
                 a single GPU, you would want to use cuDF.''')
        , (33, 9.26, np.datetime64('2020-10-15T10:58:02'), np.timedelta64(35558,'s'), 'O', 'D', 'parallel'
            , '''If you want to distribute your workflow across multiple GPUs or have more data than you can fit 
                 in memory on a single GPU you would want to use Dask-cuDF''')
        , (42, 4.21, np.datetime64('2020-10-01T10:02:23'), np.timedelta64(20480,'s'), 'U', 'C', 'GPUs'
            , 'BlazingSQL provides a high-performance distributed SQL engine in Python')
        , (36, 3.01, np.datetime64('2020-09-30T14:36:26'), np.timedelta64(24409,'s'), 'T', 'D', None
            , 'BlazingSQL is built on the RAPIDS GPU data science ecosystem')
        , (38, 6.44, np.datetime64('2020-10-10T08:34:36'), np.timedelta64(90171,'s'), 'X', 'B', 'csv'
            , 'BlazingSQL lets you ETL raw data directly into GPU memory as a GPU DataFrame (GDF)')
        , (17, 5.28, np.datetime64('2020-10-09T08:34:40'), np.timedelta64(30532,'s'), 'P', 'D', 'dataframes'
            , 'Dask is a flexible library for parallel computing in Python')
        , (10, 8.28, np.datetime64('2020-10-03T03:31:21'), np.timedelta64(23552,'s'), 'W', 'B', 'python'
            , None)
    ]
    , columns = ['num', 'float', 'datetime', 'timedelta', 'char', 'category', 'word', 'string']
)
df['category'] = df['category'].astype('category')

# %% [markdown]
# ---
#
# # Transforming
#
# ---

# %% [markdown]
# ## <span style="color:blue">DataFrame</span>

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.add_column()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.add()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.append()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.apply_chunks()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.apply_rows()

# %%
def regression(a, b, output, A_coeff, B_coeff, constant):
    for i, (aa, bb) in enumerate(zip(a,b)):
        output[i] = A_coeff * aa + B_coeff * bb + constant
        
df.apply_rows(
    regression
    , incols = {'num': 'a', 'float': 'b'}
    , outcols = {'output': np.float64}
    , kwargs = {'A_coeff': 0.21, 'B_coeff': -2.82, 'constant': 3.43}
)
# Out:
#    num  float             datetime        timedelta char category        word  \
# 0   39   6.88  2020-10-08 12:12:01  0 days 03:59:38    C        D        data
# 1   11   4.21                 <NA>             <NA>    A        D        cuDF
# 2   31   4.71  2020-10-10 09:26:43  0 days 03:35:09    U        D      memory
# 3   40   0.93  2020-10-11 17:10:00  0 days 02:54:26    P        B     tabular
# 4   33   9.26  2020-10-15 10:58:02  0 days 09:52:38    O        D    parallel
# 5   42   4.21  2020-10-01 10:02:23  0 days 05:41:20    U        C        GPUs
# 6   36   3.01  2020-09-30 14:36:26  0 days 06:46:49    T        D        <NA>
# 7   38   6.44  2020-10-10 08:34:36  1 days 01:02:51    X        B         csv
# 8   17   5.28  2020-10-09 08:34:40  0 days 08:28:52    P        D  dataframes
# 9   10   8.28  2020-10-03 03:31:21  0 days 06:32:32    W        B      python
#
#                                               string   output
# ...

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.argsort()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.assign()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.astype()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.clip()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.copy()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.drop_duplicates()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.drop()

# %%
df.drop(1)
# Out:
#    num  float            datetime       timedelta char category        word  \
# 0   39   6.88 2020-10-08 12:12:01 0 days 03:59:38    C        D        data
# 2   31   4.71 2020-10-10 09:26:43 0 days 03:35:09    U        D      memory
# 3   40   0.93 2020-10-11 17:10:00 0 days 02:54:26    P        B     tabular
# 4   33   9.26 2020-10-15 10:58:02 0 days 09:52:38    O        D    parallel
# 5   42   4.21 2020-10-01 10:02:23 0 days 05:41:20    U        C        GPUs
# 6   36   3.01 2020-09-30 14:36:26 0 days 06:46:49    T        D        <NA>
# 7   38   6.44 2020-10-10 08:34:36 1 days 01:02:51    X        B         csv
# 8   17   5.28 2020-10-09 08:34:40 0 days 08:28:52    P        D  dataframes
# 9   10   8.28 2020-10-03 03:31:21 0 days 06:32:32    W        B      python
#
#                                               string
# 0  RAPIDS.ai is a suite of open-source libraries ...
# 2  cuDF allows for loading, joining, aggregating,...
# ...

# %%
df.drop(range(1,7))
# Out:
#    num  float            datetime       timedelta char category        word  \
# 0   39   6.88 2020-10-08 12:12:01 0 days 03:59:38    C        D        data
# 7   38   6.44 2020-10-10 08:34:36 1 days 01:02:51    X        B         csv
# 8   17   5.28 2020-10-09 08:34:40 0 days 08:28:52    P        D  dataframes
# 9   10   8.28 2020-10-03 03:31:21 0 days 06:32:32    W        B      python
#
#                                               string
# 0  RAPIDS.ai is a suite of open-source libraries ...
# 7  BlazingSQL lets you ETL raw data directly into...
# 8  Dask is a flexible library for parallel comput...
# 9                                               <NA>

# %%
df.drop('word', axis=1)
# Out:
#    num  float             datetime        timedelta char category  \
# 0   39   6.88  2020-10-08 12:12:01  0 days 03:59:38    C        D
# 1   11   4.21                 <NA>             <NA>    A        D
# 2   31   4.71  2020-10-10 09:26:43  0 days 03:35:09    U        D
# 3   40   0.93  2020-10-11 17:10:00  0 days 02:54:26    P        B
# 4   33   9.26  2020-10-15 10:58:02  0 days 09:52:38    O        D
# 5   42   4.21  2020-10-01 10:02:23  0 days 05:41:20    U        C
# 6   36   3.01  2020-09-30 14:36:26  0 days 06:46:49    T        D
# 7   38   6.44  2020-10-10 08:34:36  1 days 01:02:51    X        B
# 8   17   5.28  2020-10-09 08:34:40  0 days 08:28:52    P        D
# 9   10   8.28  2020-10-03 03:31:21  0 days 06:32:32    W        B
#
#                                               string
# 0  RAPIDS.ai is a suite of open-source libraries ...
# 1  cuDF is a Python GPU DataFrame (built on the A...
# 2  cuDF allows for loading, joining, aggregating,...
# ...

# %%
df.drop(['word', 'category'], axis=1)
# Out:
#    num  float             datetime        timedelta char  \
# 0   39   6.88  2020-10-08 12:12:01  0 days 03:59:38    C
# 1   11   4.21                 <NA>             <NA>    A
# 2   31   4.71  2020-10-10 09:26:43  0 days 03:35:09    U
# 3   40   0.93  2020-10-11 17:10:00  0 days 02:54:26    P
# 4   33   9.26  2020-10-15 10:58:02  0 days 09:52:38    O
# 5   42   4.21  2020-10-01 10:02:23  0 days 05:41:20    U
# 6   36   3.01  2020-09-30 14:36:26  0 days 06:46:49    T
# 7   38   6.44  2020-10-10 08:34:36  1 days 01:02:51    X
# 8   17   5.28  2020-10-09 08:34:40  0 days 08:28:52    P
# 9   10   8.28  2020-10-03 03:31:21  0 days 06:32:32    W
#
#                                               string
# 0  RAPIDS.ai is a suite of open-source libraries ...
# 1  cuDF is a Python GPU DataFrame (built on the A...
# 2  cuDF allows for loading, joining, aggregating,...
# 3  If your workflow is fast enough on a single GP...
# 4  If you want to distribute your workflow across...
# ...

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.dropna()

# %%
df.dropna()
# Out:
#    num  float            datetime       timedelta char category        word  \
# 0   39   6.88 2020-10-08 12:12:01 0 days 03:59:38    C        D        data
# 2   31   4.71 2020-10-10 09:26:43 0 days 03:35:09    U        D      memory
# 3   40   0.93 2020-10-11 17:10:00 0 days 02:54:26    P        B     tabular
# 4   33   9.26 2020-10-15 10:58:02 0 days 09:52:38    O        D    parallel
# 5   42   4.21 2020-10-01 10:02:23 0 days 05:41:20    U        C        GPUs
# 7   38   6.44 2020-10-10 08:34:36 1 days 01:02:51    X        B         csv
# 8   17   5.28 2020-10-09 08:34:40 0 days 08:28:52    P        D  dataframes
#
#                                               string
# 0  RAPIDS.ai is a suite of open-source libraries ...
# 2  cuDF allows for loading, joining, aggregating,...
# 3  If your workflow is fast enough on a single GP...
# 4  If you want to distribute your workflow across...
# 5  BlazingSQL provides a high-performance distrib...
# ...

# %%
df.dropna(subset=['datetime'])
# Out:
#    num  float            datetime       timedelta char category        word  \
# 0   39   6.88 2020-10-08 12:12:01 0 days 03:59:38    C        D        data
# 2   31   4.71 2020-10-10 09:26:43 0 days 03:35:09    U        D      memory
# 3   40   0.93 2020-10-11 17:10:00 0 days 02:54:26    P        B     tabular
# 4   33   9.26 2020-10-15 10:58:02 0 days 09:52:38    O        D    parallel
# 5   42   4.21 2020-10-01 10:02:23 0 days 05:41:20    U        C        GPUs
# 6   36   3.01 2020-09-30 14:36:26 0 days 06:46:49    T        D        <NA>
# 7   38   6.44 2020-10-10 08:34:36 1 days 01:02:51    X        B         csv
# 8   17   5.28 2020-10-09 08:34:40 0 days 08:28:52    P        D  dataframes
# 9   10   8.28 2020-10-03 03:31:21 0 days 06:32:32    W        B      python
#
#                                               string
# 0  RAPIDS.ai is a suite of open-source libraries ...
# 2  cuDF allows for loading, joining, aggregating,...
# ...

# %%
df.dropna(how='all')
# Out:
#    num  float             datetime        timedelta char category        word  \
# 0   39   6.88  2020-10-08 12:12:01  0 days 03:59:38    C        D        data
# 1   11   4.21                 <NA>             <NA>    A        D        cuDF
# 2   31   4.71  2020-10-10 09:26:43  0 days 03:35:09    U        D      memory
# 3   40   0.93  2020-10-11 17:10:00  0 days 02:54:26    P        B     tabular
# 4   33   9.26  2020-10-15 10:58:02  0 days 09:52:38    O        D    parallel
# 5   42   4.21  2020-10-01 10:02:23  0 days 05:41:20    U        C        GPUs
# 6   36   3.01  2020-09-30 14:36:26  0 days 06:46:49    T        D        <NA>
# 7   38   6.44  2020-10-10 08:34:36  1 days 01:02:51    X        B         csv
# 8   17   5.28  2020-10-09 08:34:40  0 days 08:28:52    P        D  dataframes
# 9   10   8.28  2020-10-03 03:31:21  0 days 06:32:32    W        B      python
#
#                                               string
# 0  RAPIDS.ai is a suite of open-source libraries ...
# ...

# %%
df.dropna(axis=1)
# Out:
#    num  float char category
# 0   39   6.88    C        D
# 1   11   4.21    A        D
# 2   31   4.71    U        D
# 3   40   0.93    P        B
# 4   33   9.26    O        D
# 5   42   4.21    U        C
# 6   36   3.01    T        D
# 7   38   6.44    X        B
# 8   17   5.28    P        D
# 9   10   8.28    W        B

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.fillna()

# %%
df.fillna(1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-3f464d222635> in <module>
# ----> 1 df.fillna(1)
#
# /opt/conda/envs/rapids/lib/python3.7/site-packages/cudf/core/frame.py in fillna(self, value, method, axis, inplace, limit)
#    1323         for name in copy_data.keys():
#    1324             if name in value and value[name] is not None:
# -> 1325                 copy_data[name] = copy_data[name].fillna(value[name],)
#    1326
#    1327         result = self._from_table(Frame(copy_data, self._index))
#
# /opt/conda/envs/rapids/lib/python3.7/site-packages/cudf/core/column/timedelta.py in fillna(self, fill_value)
#     269             fill_value = column.as_column(fill_value, nan_as_null=False)
#     270
# --> 271         result = libcudf.replace.replace_nulls(col, fill_value)
#     272         if isinstance(fill_value, np.timedelta64) and np.isnat(fill_value):
# ...

# %%
df.fillna({'num': 1})
# Out:
#    num  float             datetime        timedelta char category        word  \
# 0   39   6.88  2020-10-08 12:12:01  0 days 03:59:38    C        D        data
# 1   11   4.21                 <NA>             <NA>    A        D        cuDF
# 2   31   4.71  2020-10-10 09:26:43  0 days 03:35:09    U        D      memory
# 3   40   0.93  2020-10-11 17:10:00  0 days 02:54:26    P        B     tabular
# 4   33   9.26  2020-10-15 10:58:02  0 days 09:52:38    O        D    parallel
# 5   42   4.21  2020-10-01 10:02:23  0 days 05:41:20    U        C        GPUs
# 6   36   3.01  2020-09-30 14:36:26  0 days 06:46:49    T        D        <NA>
# 7   38   6.44  2020-10-10 08:34:36  1 days 01:02:51    X        B         csv
# 8   17   5.28  2020-10-09 08:34:40  0 days 08:28:52    P        D  dataframes
# 9   10   8.28  2020-10-03 03:31:21  0 days 06:32:32    W        B      python
#
#                                               string
# 0  RAPIDS.ai is a suite of open-source libraries ...
# ...

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.hash_columns()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.insert()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.interleave_columns()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.join()

# %%
categories = cudf.DataFrame([
    ('B', 'cuDF')
    , ('C', 'BlazingSQL')
    , ('D', 'Dask')
], columns=['cat', 'name'])

df.join(categories)
# Out:
#    num  float             datetime        timedelta char category        word  \
# 0   39   6.88  2020-10-08 12:12:01  0 days 03:59:38    C        D        data
# 1   11   4.21                 <NA>             <NA>    A        D        cuDF
# 2   31   4.71  2020-10-10 09:26:43  0 days 03:35:09    U        D      memory
# 3   40   0.93  2020-10-11 17:10:00  0 days 02:54:26    P        B     tabular
# 4   33   9.26  2020-10-15 10:58:02  0 days 09:52:38    O        D    parallel
# 5   42   4.21  2020-10-01 10:02:23  0 days 05:41:20    U        C        GPUs
# 6   36   3.01  2020-09-30 14:36:26  0 days 06:46:49    T        D        <NA>
# 7   38   6.44  2020-10-10 08:34:36  1 days 01:02:51    X        B         csv
# 8   17   5.28  2020-10-09 08:34:40  0 days 08:28:52    P        D  dataframes
# 9   10   8.28  2020-10-03 03:31:21  0 days 06:32:32    W        B      python
#
#                                               string   cat        name
# ...

# %%
df.join(categories, lsuffix='_l', rsuffix='_r', how='left')
# Out:
#    num  float             datetime        timedelta char category        word  \
# 0   39   6.88  2020-10-08 12:12:01  0 days 03:59:38    C        D        data
# 1   11   4.21                 <NA>             <NA>    A        D        cuDF
# 2   31   4.71  2020-10-10 09:26:43  0 days 03:35:09    U        D      memory
# 3   40   0.93  2020-10-11 17:10:00  0 days 02:54:26    P        B     tabular
# 4   33   9.26  2020-10-15 10:58:02  0 days 09:52:38    O        D    parallel
# 5   42   4.21  2020-10-01 10:02:23  0 days 05:41:20    U        C        GPUs
# 6   36   3.01  2020-09-30 14:36:26  0 days 06:46:49    T        D        <NA>
# 7   38   6.44  2020-10-10 08:34:36  1 days 01:02:51    X        B         csv
# 8   17   5.28  2020-10-09 08:34:40  0 days 08:28:52    P        D  dataframes
# 9   10   8.28  2020-10-03 03:31:21  0 days 06:32:32    W        B      python
#
#                                               string   cat        name
# ...

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.label_encoding()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.mask()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.melt()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.merge()

# %%
categories = cudf.DataFrame([
    ('B', 'cuDF')
    , ('C', 'BlazingSQL')
    , ('D', 'Dask')
], columns=['category', 'name'])

# %%
df.merge(categories, on='category')
# Out:
#    num  float             datetime        timedelta char category        word  \
# 0   39   6.88  2020-10-08 12:12:01  0 days 03:59:38    C        D        data
# 1   11   4.21                 <NA>             <NA>    A        D        cuDF
# 2   31   4.71  2020-10-10 09:26:43  0 days 03:35:09    U        D      memory
# 3   40   0.93  2020-10-11 17:10:00  0 days 02:54:26    P        B     tabular
# 4   33   9.26  2020-10-15 10:58:02  0 days 09:52:38    O        D    parallel
# 5   42   4.21  2020-10-01 10:02:23  0 days 05:41:20    U        C        GPUs
# 6   36   3.01  2020-09-30 14:36:26  0 days 06:46:49    T        D        <NA>
# 7   38   6.44  2020-10-10 08:34:36  1 days 01:02:51    X        B         csv
# 8   17   5.28  2020-10-09 08:34:40  0 days 08:28:52    P        D  dataframes
# 9   10   8.28  2020-10-03 03:31:21  0 days 06:32:32    W        B      python
#
#                                               string        name
# ...

# %%
df.merge(categories, on='category', how='left')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-5632bc82861a> in <module>
# ----> 1 df.merge(categories, on='category', how='left')
#
# /opt/conda/envs/rapids/lib/python3.7/contextlib.py in inner(*args, **kwds)
#      72         def inner(*args, **kwds):
#      73             with self._recreate_cm():
# ---> 74                 return func(*args, **kwds)
#      75         return inner
#      76
#
# /opt/conda/envs/rapids/lib/python3.7/site-packages/cudf/core/dataframe.py in merge(self, right, on, left_on, right_on, left_index, right_index, how, sort, lsuffix, rsuffix, type, method, indicator, suffixes)
#    3983             method=method,
#    3984             indicator=indicator,
# -> 3985             suffixes=suffixes,
#    3986         )
#    3987         return gdf_result
#
# ...

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.nans_to_nulls()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.one_hot_encoding()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.partition_by_hash()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.pivot()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.radd()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.rank()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.rdiv()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.reindex()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.rename()

# %%
df.rename({0: 100})
# Out:
#      num  float             datetime        timedelta char category  \
# 100   39   6.88  2020-10-08 12:12:01  0 days 03:59:38    C        D
# 1     11   4.21                 <NA>             <NA>    A        D
# 2     31   4.71  2020-10-10 09:26:43  0 days 03:35:09    U        D
# 3     40   0.93  2020-10-11 17:10:00  0 days 02:54:26    P        B
# 4     33   9.26  2020-10-15 10:58:02  0 days 09:52:38    O        D
# 5     42   4.21  2020-10-01 10:02:23  0 days 05:41:20    U        C
# 6     36   3.01  2020-09-30 14:36:26  0 days 06:46:49    T        D
# 7     38   6.44  2020-10-10 08:34:36  1 days 01:02:51    X        B
# 8     17   5.28  2020-10-09 08:34:40  0 days 08:28:52    P        D
# 9     10   8.28  2020-10-03 03:31:21  0 days 06:32:32    W        B
#
#            word                                             string
# 100        data  RAPIDS.ai is a suite of open-source libraries ...
# 1          cuDF  cuDF is a Python GPU DataFrame (built on the A...
# ...

# %%
df.rename({'num': 'numbers'}, axis=1)
# Out:
#    numbers  float             datetime        timedelta char category  \
# 0       39   6.88  2020-10-08 12:12:01  0 days 03:59:38    C        D
# 1       11   4.21                 <NA>             <NA>    A        D
# 2       31   4.71  2020-10-10 09:26:43  0 days 03:35:09    U        D
# 3       40   0.93  2020-10-11 17:10:00  0 days 02:54:26    P        B
# 4       33   9.26  2020-10-15 10:58:02  0 days 09:52:38    O        D
# 5       42   4.21  2020-10-01 10:02:23  0 days 05:41:20    U        C
# 6       36   3.01  2020-09-30 14:36:26  0 days 06:46:49    T        D
# 7       38   6.44  2020-10-10 08:34:36  1 days 01:02:51    X        B
# 8       17   5.28  2020-10-09 08:34:40  0 days 08:28:52    P        D
# 9       10   8.28  2020-10-03 03:31:21  0 days 06:32:32    W        B
#
#          word                                             string
# 0        data  RAPIDS.ai is a suite of open-source libraries ...
# 1        cuDF  cuDF is a Python GPU DataFrame (built on the A...
# ...

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.repeat()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.replace()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.reset_index()

# %%
df.reset_index()
# Out:
#    index  num  float             datetime        timedelta char category  \
# 0      0   39   6.88  2020-10-08 12:12:01  0 days 03:59:38    C        D
# 1      1   11   4.21                 <NA>             <NA>    A        D
# 2      2   31   4.71  2020-10-10 09:26:43  0 days 03:35:09    U        D
# 3      3   40   0.93  2020-10-11 17:10:00  0 days 02:54:26    P        B
# 4      4   33   9.26  2020-10-15 10:58:02  0 days 09:52:38    O        D
# 5      5   42   4.21  2020-10-01 10:02:23  0 days 05:41:20    U        C
# 6      6   36   3.01  2020-09-30 14:36:26  0 days 06:46:49    T        D
# 7      7   38   6.44  2020-10-10 08:34:36  1 days 01:02:51    X        B
# 8      8   17   5.28  2020-10-09 08:34:40  0 days 08:28:52    P        D
# 9      9   10   8.28  2020-10-03 03:31:21  0 days 06:32:32    W        B
#
#          word                                             string
# 0        data  RAPIDS.ai is a suite of open-source libraries ...
# ...

# %%
df.reset_index(drop=True)
# Out:
#    num  float             datetime        timedelta char category        word  \
# 0   39   6.88  2020-10-08 12:12:01  0 days 03:59:38    C        D        data
# 1   11   4.21                 <NA>             <NA>    A        D        cuDF
# 2   31   4.71  2020-10-10 09:26:43  0 days 03:35:09    U        D      memory
# 3   40   0.93  2020-10-11 17:10:00  0 days 02:54:26    P        B     tabular
# 4   33   9.26  2020-10-15 10:58:02  0 days 09:52:38    O        D    parallel
# 5   42   4.21  2020-10-01 10:02:23  0 days 05:41:20    U        C        GPUs
# 6   36   3.01  2020-09-30 14:36:26  0 days 06:46:49    T        D        <NA>
# 7   38   6.44  2020-10-10 08:34:36  1 days 01:02:51    X        B         csv
# 8   17   5.28  2020-10-09 08:34:40  0 days 08:28:52    P        D  dataframes
# 9   10   8.28  2020-10-03 03:31:21  0 days 06:32:32    W        B      python
#
#                                               string
# 0  RAPIDS.ai is a suite of open-source libraries ...
# ...

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.rfloordiv()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.rmod()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.rmul()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.rolling()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.rpow()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.rsub()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.rtruediv()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.scatter_by_map()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.set_index()

# %%
df.set_index('category')
# Out:
#           num  float             datetime        timedelta char        word  \
# category
# D          39   6.88  2020-10-08 12:12:01  0 days 03:59:38    C        data
# D          11   4.21                 <NA>             <NA>    A        cuDF
# D          31   4.71  2020-10-10 09:26:43  0 days 03:35:09    U      memory
# B          40   0.93  2020-10-11 17:10:00  0 days 02:54:26    P     tabular
# D          33   9.26  2020-10-15 10:58:02  0 days 09:52:38    O    parallel
# C          42   4.21  2020-10-01 10:02:23  0 days 05:41:20    U        GPUs
# D          36   3.01  2020-09-30 14:36:26  0 days 06:46:49    T        <NA>
# B          38   6.44  2020-10-10 08:34:36  1 days 01:02:51    X         csv
# D          17   5.28  2020-10-09 08:34:40  0 days 08:28:52    P  dataframes
# B          10   8.28  2020-10-03 03:31:21  0 days 06:32:32    W      python
#
#                                                      string
# category
# ...

# %%
df.set_index('category', drop=False)
# Out:
#           num  float             datetime        timedelta char category  \
# category
# D          39   6.88  2020-10-08 12:12:01  0 days 03:59:38    C        D
# D          11   4.21                 <NA>             <NA>    A        D
# D          31   4.71  2020-10-10 09:26:43  0 days 03:35:09    U        D
# B          40   0.93  2020-10-11 17:10:00  0 days 02:54:26    P        B
# D          33   9.26  2020-10-15 10:58:02  0 days 09:52:38    O        D
# C          42   4.21  2020-10-01 10:02:23  0 days 05:41:20    U        C
# D          36   3.01  2020-09-30 14:36:26  0 days 06:46:49    T        D
# B          38   6.44  2020-10-10 08:34:36  1 days 01:02:51    X        B
# D          17   5.28  2020-10-09 08:34:40  0 days 08:28:52    P        D
# B          10   8.28  2020-10-03 03:31:21  0 days 06:32:32    W        B
#
#                 word                                             string
# category
# D               data  RAPIDS.ai is a suite of open-source libraries ...
# ...

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.shift()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.sort_index()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.sort_values()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.stack()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.sub()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.tile()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.transpose()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.truediv()

# %% [markdown]
# #### cudf.core.dataframe.DataFrame.unstack()

# %% [markdown]
# ## <span style="color:blue">Series</span>

# %% [markdown]
# #### cudf.core.series.Series.add()

# %% [markdown]
# #### cudf.core.series.Series.append()

# %% [markdown]
# #### cudf.core.series.Series.applymap()
# #### cudf.core.series.Series.argsort()
# #### cudf.core.series.Series.as_index()
# #### cudf.core.series.Series.as_mask()
# #### cudf.core.series.Series.astype()
# #### cudf.core.series.Series.clip()
# #### cudf.core.series.Series.copy()
# #### cudf.core.series.Series.diff()
# #### cudf.core.series.Series.digitize()
# #### cudf.core.series.Series.drop_duplicates()
# #### cudf.core.series.Series.dropna()
# #### cudf.core.series.Series.factorize()
# #### cudf.core.series.Series.fillna()
# #### cudf.core.series.Series.hash_encode()
# #### cudf.core.series.Series.interleave_columns()
# #### cudf.core.series.Series.label_encoding()
# #### cudf.core.series.Series.mask()
# #### cudf.core.series.Series.nans_to_nulls()
# #### cudf.core.series.Series.one_hot_encoding()
# #### cudf.core.series.Series.radd()
# #### cudf.core.series.Series.rank()
# #### cudf.core.series.Series.reindex()
# #### cudf.core.series.Series.rename()
# #### cudf.core.series.Series.repeat()
# #### cudf.core.series.Series.replace()
# #### cudf.core.series.Series.reset_index()
# #### cudf.core.series.Series.reverse()
# #### cudf.core.series.Series.rfloordiv()
# #### cudf.core.series.Series.rmod()
# #### cudf.core.series.Series.rmul()
# #### cudf.core.series.Series.rolling()
# #### cudf.core.series.Series.round()
# #### cudf.core.series.Series.rpow()
# #### cudf.core.series.Series.rsub()
# #### cudf.core.series.Series.rtruediv()
# #### cudf.core.series.Series.scale()
# #### cudf.core.series.Series.scatter_by_map()
# #### cudf.core.series.Series.set_index()
# #### cudf.core.series.Series.set_mask()
# #### cudf.core.series.Series.shift()
# #### cudf.core.series.Series.sort_index()
# #### cudf.core.series.Series.sort_values()
# #### cudf.core.series.Series.sub()
# #### cudf.core.series.Series.tile()
# #### cudf.core.series.Series.truediv()
